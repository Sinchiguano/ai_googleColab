# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinchiguano/ai_googleColab/blob/main/Untitled67.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/cta-ridership.csv')

# %%
df.head(5)
# Out:
#    station_id       stationname                     date daytype  rides
# 0       40350       UIC-Halsted  2001-01-01T00:00:00.000       U    273
# 1       41130    Halsted-Orange  2001-01-01T00:00:00.000       U    306
# 2       40760         Granville  2001-01-01T00:00:00.000       U   1059
# 3       40070  Jackson/Dearborn  2001-01-01T00:00:00.000       U    649
# 4       40090       Damen-Brown  2001-01-01T00:00:00.000       U    411

# %%
df.shape
# Out:
# (962546, 5)

# %%
df.describe()
# Out:
#           station_id          rides
# count  962546.000000  962546.000000
# mean    40762.733189    3318.392700
# std       446.786468    3207.487871
# min     40010.000000       0.000000
# 25%     40370.000000    1123.000000
# 50%     40750.000000    2322.000000
# 75%     41150.000000    4350.000000
# max     41700.000000   36323.000000

# %%
df['daytype'].unique()
# Out:
# array(['U', 'W', 'A'], dtype=object)

# %%
df['stationname'].value_counts()
# Out:
# stationname
# Racine                    6775
# Montrose-Brown            6773
# Western-Forest Park       6772
# Monroe/Dearborn           6772
# Montrose-O'Hare           6771
#                           ...
# Oakton-Skokie             2647
# Morgan-Lake               2617
# Cermak-McCormick Place    1642
# Washington/Wabash          699
# Homan                       31
# Name: count, Length: 148, dtype: int64

# %%
filter=df['rides']==max(df['rides'])
df[filter].head(3)
# Out:
#         station_id         stationname                     date daytype  rides
# 751826       41320  Belmont-North Main  2015-06-28T00:00:00.000       U  36323

# %%
filter=df['rides']==min(df['rides'])
df[filter].shape
# Out:
# (12197, 5)

# %%
filter=df['rides']==0
zero=df[filter]
df[filter]['stationname'].head(10)
# Out:
# 13                Skokie
# 16        Pulaski-Cermak
# 24        Western-Cermak
# 27         Kedzie-Cermak
# 55          Damen-Cermak
# 74                  Polk
# 76           54th/Cermak
# 86     California-Cermak
# 102        Cicero-Cermak
# 110                 18th
# Name: stationname, dtype: object

# %%
zerogroups=zero.groupby(['stationname','daytype']).count()
zerogroups.sort_values(by=['date'],ascending=False)
# Out:
#                           station_id  date  rides
# stationname      daytype
# Madison/Wabash   W               711   711    711
# Washington/State W               516   516    516
# Skokie           U               390   390    390
#                  A               355   355    355
# Randolph/Wabash  W               351   351    351
# ...                              ...   ...    ...
# 51st             U                 1     1      1
# Central-Evanston U                 1     1      1
# Bryn Mawr        U                 1     1      1
# Linden           U                 1     1      1
# Central-Evanston A                 1     1      1
#
# [236 rows x 3 columns]

# %%
min(df['date'])
# Out:
# '2001-01-01T00:00:00.000'

# %%
max(df['date'])
# Out:
# '2019-06-30T00:00:00.000'

# %%
df.describe()
# Out:
#           station_id          rides
# count  962546.000000  962546.000000
# mean    40762.733189    3318.392700
# std       446.786468    3207.487871
# min     40010.000000       0.000000
# 25%     40370.000000    1123.000000
# 50%     40750.000000    2322.000000
# 75%     41150.000000    4350.000000
# max     41700.000000   36323.000000

# %%
df.dtypes
# Out:
# station_id      int64
# stationname    object
# date           object
# daytype        object
# rides           int64
# dtype: object

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# station_id              int64
# stationname            object
# date           datetime64[ns]
# daytype                object
# rides                   int64
# dtype: object

# %%
df.head(3)
# Out:
#    station_id     stationname       date daytype  rides
# 0       40350     UIC-Halsted 2001-01-01       U    273
# 1       41130  Halsted-Orange 2001-01-01       U    306
# 2       40760       Granville 2001-01-01       U   1059

# %%
df.set_index('date',inplace=True)

# %%
df.head(10)
# Out:
#             station_id              stationname daytype  rides
# date
# 2001-01-01       40350              UIC-Halsted       U    273
# 2001-01-01       41130           Halsted-Orange       U    306
# 2001-01-01       40760                Granville       U   1059
# 2001-01-01       40070         Jackson/Dearborn       U    649
# 2001-01-01       40090              Damen-Brown       U    411
# 2001-01-01       40590          Damen/Milwaukee       U    870
# 2001-01-01       40720  East 63rd-Cottage Grove       U    391
# 2001-01-01       41260              Austin-Lake       U    399
# 2001-01-01       40230               Cumberland       U    788
# 2001-01-01       41120       35-Bronzeville-IIT       U    448

# %%
rides_by_date=df.sort_values(by=['date'])
rides_by_date.head(3)
# Out:
#             station_id         stationname daytype  rides
# date
# 2001-01-01       40350         UIC-Halsted       U    273
# 2001-01-01       40320  Division/Milwaukee       U    854
# 2001-01-01       40420       Cicero-Cermak       U      0

# %%
garfield_red=rides_by_date[rides_by_date['stationname']=='Garfield/Red']
garfield_red.head(3)
# Out:
# Empty DataFrame
# Columns: [station_id, stationname, daytype, rides]
# Index: []

# %%
garfield_red=rides_by_date[rides_by_date['stationname']=='Garfield-Dan Ryan']
garfield_red.head(3)
# Out:
#             station_id        stationname daytype  rides
# date
# 2001-01-01       41170  Garfield-Dan Ryan       U   1457
# 2001-01-02       41170  Garfield-Dan Ryan       W   3748
# 2001-01-03       41170  Garfield-Dan Ryan       W   3977

# %%
garfield_green=rides_by_date[rides_by_date['stationname']=='Garfield-South Elevated']
garfield_green.head(6)
# Out:
#             station_id              stationname daytype  rides
# date
# 2001-01-01       40510  Garfield-South Elevated       U    248
# 2001-01-02       40510  Garfield-South Elevated       W    617
# 2001-01-03       40510  Garfield-South Elevated       W    657
# 2001-01-04       40510  Garfield-South Elevated       W    697
# 2001-01-05       40510  Garfield-South Elevated       W    770
# 2001-01-06       40510  Garfield-South Elevated       A    443

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(rc={'figure.figsize':(11,4)})

# %%
garfield_green.head(2)
# Out:
#             station_id              stationname daytype  rides
# date
# 2001-01-01       40510  Garfield-South Elevated       U    248
# 2001-01-02       40510  Garfield-South Elevated       W    617

# %%
garfield_green['rides']. plot(linewidth=0.5)
# Out:
# <Axes: xlabel='date'>

# %%
garfield_red['rides']. plot(linewidth=0.5)
# Out:
# <Axes: xlabel='date'>

# %%
rides_by_date[rides_by_date['stationname']=='Madison/Wabash']['rides'].plot(linewidth=0.5)
# Out:
# <Axes: xlabel='date'>
