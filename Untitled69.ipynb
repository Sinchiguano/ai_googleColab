# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinchiguano/ai_googleColab/blob/main/Untitled69.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://web.stanford.edu/~hastie/ElemStatLearn/datasets/prostate.data", sep='\t')

# %%
df.describe()
# Out:
#        Unnamed: 0     lcavol    lweight        age       lbph        svi  \
# count   97.000000  97.000000  97.000000  97.000000  97.000000  97.000000
# mean    49.000000   1.350010   3.628943  63.865979   0.100356   0.216495
# std     28.145456   1.178625   0.428411   7.445117   1.450807   0.413995
# min      1.000000  -1.347074   2.374906  41.000000  -1.386294   0.000000
# 25%     25.000000   0.512824   3.375880  60.000000  -1.386294   0.000000
# 50%     49.000000   1.446919   3.623007  65.000000   0.300105   0.000000
# 75%     73.000000   2.127041   3.876396  68.000000   1.558145   0.000000
# max     97.000000   3.821004   4.780383  79.000000   2.326302   1.000000
#
#              lcp    gleason       pgg45       lpsa
# count  97.000000  97.000000   97.000000  97.000000
# mean   -0.179366   6.752577   24.381443   2.478387
# std     1.398250   0.722134   28.204035   1.154329
# min    -1.386294   6.000000    0.000000  -0.430783
# 25%    -1.386294   6.000000    0.000000   1.731656
# 50%    -0.798508   7.000000   15.000000   2.591516
# 75%     1.178655   7.000000   40.000000   3.056357
# max     2.904165   9.000000  100.000000   5.582932

# %%
del df['Unnamed: 0']

# %%
df.head(2)
# Out:
#      lcavol   lweight  age      lbph  svi       lcp  gleason  pgg45      lpsa  \
# 0 -0.579818  2.769459   50 -1.386294    0 -1.386294        6      0 -0.430783
# 1 -0.994252  3.319626   58 -1.386294    0 -1.386294        6      0 -0.162519
#
#   train
# 0     T
# 1     T

# %%
df_train=df[df['train']=='T']
df_test=df[df['train']=='F']

# %%
print(df_train.shape)
print(df_test.shape)
print(df.shape)
# Out:
# (67, 10)
# (30, 10)
# (97, 10)

# %%
df_train.drop(['train'], axis=1, inplace=True)
df_test.drop(['train'], axis=1, inplace=True)
# Out:
# <ipython-input-302-b17a58bca96f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.drop(['train'], axis=1, inplace=True)
# <ipython-input-302-b17a58bca96f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test.drop(['train'], axis=1, inplace=True)

# %%
df_train.head(3)
# Out:
#      lcavol   lweight  age      lbph  svi       lcp  gleason  pgg45      lpsa
# 0 -0.579818  2.769459   50 -1.386294    0 -1.386294        6      0 -0.430783
# 1 -0.994252  3.319626   58 -1.386294    0 -1.386294        6      0 -0.162519
# 2 -0.510826  2.691243   74 -1.386294    0 -1.386294        7     20 -0.162519

# %%
df_test.head(3)
# Out:
#      lcavol   lweight  age      lbph  svi       lcp  gleason  pgg45      lpsa
# 6  0.737164  3.473518   64  0.615186    0 -1.386294        6      0  0.765468
# 8 -0.776529  3.539509   47 -1.386294    0 -1.386294        6      0  1.047319
# 9  0.223144  3.244544   63 -1.386294    0 -1.386294        6      0  1.047319

# %%
df_train.corr()
# Out:
#            lcavol   lweight       age      lbph       svi       lcp   gleason  \
# lcavol   1.000000  0.300232  0.286324  0.063168  0.592949  0.692043  0.426414
# lweight  0.300232  1.000000  0.316723  0.437042  0.181054  0.156829  0.023558
# age      0.286324  0.316723  1.000000  0.287346  0.128902  0.172951  0.365915
# lbph     0.063168  0.437042  0.287346  1.000000 -0.139147 -0.088535  0.032992
# svi      0.592949  0.181054  0.128902 -0.139147  1.000000  0.671240  0.306875
# lcp      0.692043  0.156829  0.172951 -0.088535  0.671240  1.000000  0.476437
# gleason  0.426414  0.023558  0.365915  0.032992  0.306875  0.476437  1.000000
# pgg45    0.483161  0.074166  0.275806 -0.030404  0.481358  0.662533  0.757056
# lpsa     0.733155  0.485215  0.227642  0.262938  0.556886  0.489203  0.342428
#
#             pgg45      lpsa
# lcavol   0.483161  0.733155
# lweight  0.074166  0.485215
# age      0.275806  0.227642
# lbph    -0.030404  0.262938
# svi      0.481358  0.556886
# lcp      0.662533  0.489203
# gleason  0.757056  0.342428
# pgg45    1.000000  0.448048
# lpsa     0.448048  1.000000

# %%
import matplotlib.pyplot as plt

plt.matshow(df_train.corr())
plt.show()

# %%
df.describe().loc[['mean','std']]
# Out:
#         lcavol   lweight        age      lbph       svi       lcp   gleason  \
# mean  1.350010  3.628943  63.865979  0.100356  0.216495 -0.179366  6.752577
# std   1.178625  0.428411   7.445117  1.450807  0.413995  1.398250  0.722134
#
#           pgg45      lpsa
# mean  24.381443  2.478387
# std   28.204035  1.154329

# %%
import numpy as np
from sklearn import datasets, linear_model

# %%
model=linear_model.LinearRegression()

# %%
iterator = pd.DataFrame(df.iloc[:,:-1]).items() #Will not change the response, only the predictors.

# print(iterator)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
print(df.describe().loc[['mean','std']])

def normalize(df):
    iterator = pd.DataFrame(df.iloc[:,:-1]).items() #Will not change the response, only the predictors.
    for column,_ in iterator:
        column_data = pd.DataFrame(df[column]) # Create dataframe with a single column.
        new_column_array = scaler.fit_transform(column_data) # The scaler transforms the column.
        df[column] = pd.DataFrame(new_column_array) # Update column.
    return df

df.head(1)
# Out:
#         lcavol   lweight        age      lbph       svi       lcp   gleason  \
# mean  1.350010  3.628943  63.865979  0.100356  0.216495 -0.179366  6.752577
# std   1.178625  0.428411   7.445117  1.450807  0.413995  1.398250  0.722134
#
#           pgg45      lpsa
# mean  24.381443  2.478387
# std   28.204035  1.154329
#      lcavol   lweight  age      lbph  svi       lcp  gleason  pgg45      lpsa  \
# 0 -0.579818  2.769459   50 -1.386294    0 -1.386294        6      0 -0.430783
#
#   train
# 0     T

# %%
df = pd.read_csv("https://web.stanford.edu/~hastie/ElemStatLearn/datasets/prostate.data", sep='\t')

train=df['train']
# print(df.head(3))
df=normalize(df.drop(['train'], axis=1))
df['train']=train
del df['Unnamed: 0']
print(df.head(3))

print(df.describe().loc[['mean','std']])
# Out:
#      lcavol   lweight       age      lbph       svi       lcp   gleason  \
# 0 -1.645861 -2.016634 -1.872101 -1.030029 -0.525657 -0.867655 -1.047571
# 1 -1.999313 -0.725759 -0.791989 -1.030029 -0.525657 -0.867655 -1.047571
# 2 -1.587021 -2.200154  1.368234 -1.030029 -0.525657 -0.867655  0.344407
#
#       pgg45      lpsa train
# 0 -0.868957 -0.430783     T
# 1 -0.868957 -0.162519     T
# 2 -0.156155 -0.162519     T
#             lcavol       lweight           age          lbph           svi  \
# mean  4.578239e-17  6.844468e-16  4.131861e-16 -2.432190e-17 -3.662591e-17
# std   1.005195e+00  1.005195e+00  1.005195e+00  1.005195e+00  1.005195e+00
#
#                lcp       gleason         pgg45      lpsa
# mean  3.662591e-17 -2.174664e-17  5.636957e-17  2.478387
# std   1.005195e+00  1.005195e+00  1.005195e+00  1.154329

# %%
df_train=df[df['train']=='T']
df_test=df[df['train']=='F']

# %%
train_features = df_train.loc[:,'lcavol':'pgg45']
train_targets = df_train.loc[:,'lpsa']

test_features = df_test.loc[:,'lcavol':'pgg45']
test_targets = df_test.loc[:,'lpsa']

# %%
train_features.shape
# Out:
# (67, 8)

# %%
train_targets.shape
# Out:
# (67,)

# %%
train_features.head(3)
# Out:
#      lcavol   lweight       age      lbph       svi       lcp   gleason  \
# 0 -1.645861 -2.016634 -1.872101 -1.030029 -0.525657 -0.867655 -1.047571
# 1 -1.999313 -0.725759 -0.791989 -1.030029 -0.525657 -0.867655 -1.047571
# 2 -1.587021 -2.200154  1.368234 -1.030029 -0.525657 -0.867655  0.344407
#
#       pgg45
# 0 -0.868957
# 1 -0.868957
# 2 -0.156155

# %%
model.fit(train_features,train_targets)
# Out:
# LinearRegression()

# %%
predicted=model.predict(test_features)
print(predicted)
# Out:
# [1.96903844 1.16995577 1.26117929 1.88375914 2.54431886 1.93275402
#  2.04233571 1.83091625 1.99115929 1.32347076 2.93843111 2.20314404
#  2.166421   2.79456237 2.67466879 2.18057291 2.40211068 3.02351576
#  3.21122283 1.38441459 3.41751878 3.70741749 2.54118337 2.72969658
#  2.64055575 3.48060024 3.17136269 3.2923494  3.11889686 3.76383999]

# %%
print("Mean squared error: %.2f"%np.mean((predicted-test_targets)**2))
print("RSS %.2f"%np.sum((predicted-test_targets)**2))
# Out:
# Mean squared error: 0.52
# RSS 15.64

# %%
from sklearn.metrics import mean_squared_error, r2_score
print('variance score: %.2f'%model.score(train_features,train_targets))

from sklearn.metrics import explained_variance_score

# Assuming y_true contains actual values and y_pred contains predicted values
variance_score = explained_variance_score(test_targets, predicted)
print(variance_score) #To see the output, run the code.
# Out:
# variance score: 0.69
# 0.505182698800625

# %%
def Z_score(X_train, y_true, y_pred, beta_hat):
    '''
    Returns the Z-scores of the model with coefficients beta_hat.
    The data is encoded in X_train and y_true:
        X_train is a (numpy) array (N, p + 1), where p is the number of predictors.
        y_true is a vector of length N.
    y_pred ia vector of length N, and is the prediction of the model on X.
    '''
    N = len(y_true)
    p = X_train.shape[1] - 1
    variance_y_est = (1/(N-p-1)) * np.sum(np.square(y_true - y_pred)) # Estimative of the variance of y.
    diag = np.diag(np.linalg.inv(np.matmul(np.transpose(X_train),X_train))) # Diagonal of (X^t X)^{-1}.
    Z = (1/np.sqrt(variance_y_est)) * np.multiply(beta_hat, np.sqrt(1/diag))
    return Z

# %%
# The predicted values of y on the training set.
y_pred = model.predict(train_features)

# # prepare beta
beta_hat = model.coef_
beta_hat = np.concatenate([np.array([model.intercept_]), beta_hat])

# # prepare X
column_of_ones = np.ones((train_features.shape[0],1))
print(column_of_ones.shape)
# print(column_of_ones)
# print(train_features.shape )
X = np.concatenate([column_of_ones, train_features], axis = 1)
# print(X[:1])

# # Z-scores
columns = ['Intercept'] + train_features.columns.to_list()
Zscores = np.array([Z_score(X, train_targets.to_numpy(), y_pred, beta_hat)])
Zscores_df = pd.DataFrame(data=Zscores, columns=columns, index=['Z-score'] )
Zscores
# Out:
# (67, 1)
# array([[27.59820312,  5.36629046,  2.75078939, -1.39590898,  2.05584563,
#          2.46925518, -1.86691264, -0.14668121,  1.73783972]])

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'column_name' is the column you want to calculate z-scores for
df['z_scores'] = (df['lcavol'] - df['lcavol'].mean()) / df['lcavol'].std()
print(df.head(2)) #To see the output, run the code.
# Out:
#      lcavol   lweight       age      lbph       svi       lcp   gleason  \
# 0 -1.645861 -2.016634 -1.872101 -1.030029 -0.525657 -0.867655 -1.047571
# 1 -1.999313 -0.725759 -0.791989 -1.030029 -0.525657 -0.867655 -1.047571
#
#       pgg45      lpsa train  z_scores
# 0 -0.868957 -0.430783     T -1.637356
# 1 -0.868957 -0.162519     T -1.988980

# %%
train_features_small = df_train.loc[:,['lcavol','lweight','svi']]
test_features_small = df_test.loc[:,['lcavol','lweight','svi']]
model.fit(train_features_small,train_targets)
target_predict_small = model.predict(test_features_small)

# The mean squared error and RSS (by hand)
print("Mean squared error: %.2f" % np.mean((target_predict_small - test_targets) ** 2))
print("RSS: %.2f" % np.sum((target_predict_small - test_targets) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % model.score(train_features_small, train_targets))
# Out:
# Mean squared error: 0.40
# RSS: 12.02
# Variance score: 0.64

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

def random_data(beta, n, std_dev, maxval=100):

    # Generate x as an array of `n` samples which can take a value between 0 and 100
    x = np.random.rand(n) * maxval

    # Generate the random error of n samples, with a random value from a normal distribution, with a standard
    # deviation provided in the function argument
    e = np.random.randn(n) * std_dev

    # Calculate `y` according to the equation discussed
    y = x * beta + e
    return x, y

# %%
x,y = random_data(10, 50, 100)
plt.xlabel('X')
plt.ylabel('Y')
plt.scatter(x,y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33, random_state=42)

print("Size of train sample: ", len(X_train))
print("Size of test sample: ", len(X_test))
# Out:
# Size of train sample:  33
# Size of test sample:  17

# %%
from scipy.optimize import minimize

# A simplified computation of the negative log likelihood, based on the derivation above.

def negative_ll(theta):
    (m, b, sigma) = theta

    y  = m*X_train + b

    # Exponent from log likelihood that we are trying to maximize
    # We negate the term so that we can minimize it.
    L = (1 / (2 * sigma ** 2) * sum((y - y_train) ** 2))
    return L


# minimuze
MLE = minimize(negative_ll, np.array([1,1,1]), method='L-BFGS-B')

(m, b, sigma) = MLE['x']

plt.scatter(X_train,y_train)
plt.plot(x, m*x + b)
plt.show()
